# %%
import numpy as np
import pandas as pd

def make_df(cols, ind):
    data = {c: [str(c) + str(i) for i in ind] for c in cols}
    return pd.DataFrame(data, ind)

# %%
make_df('ABCDE', range(8))
# Out:
#     A   B   C   D   E
# 0  A0  B0  C0  D0  E0
# 1  A1  B1  C1  D1  E1
# 2  A2  B2  C2  D2  E2
# 3  A3  B3  C3  D3  E3
# 4  A4  B4  C4  D4  E4
# 5  A5  B5  C5  D5  E5
# 6  A6  B6  C6  D6  E6
# 7  A7  B7  C7  D7  E7
